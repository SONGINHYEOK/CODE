# %% [markdown]
# # 학습 목표
# 1. 리간드 기반 스크리닝 데이터를 수집하는 방법을 알아본다.
# 2. 데이터 전처리 방법을 알아본다.

# %% [markdown]
# https://pubchem.ncbi.nlm.nih.gov/bioassay/1890

# %%
import requests
import pandas as pd

# PubChem BioAssay의 AID 설정 : 1890
assay_id = "1890"
# PubChem PUG REST API URL (CSV 형식 요청)
url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/assay/aid/{assay_id}/CSV"
print(f"AID {assay_id}의 assay 데이터를 다운로드 중입니다...")

# 데이터 다운로드
response = requests.get(url)
csv_filename = f"assay_{assay_id}.csv"
with open(csv_filename, "w", encoding="utf-8") as file:
    file.write(response.text)

# pandas를 통해 CSV 파일 로드 및 미리보기
df = pd.read_csv(csv_filename)
df
# Out:
# AID 1890의 assay 데이터를 다운로드 중입니다...
#                  PUBCHEM_RESULT_TAG  PUBCHEM_SID  PUBCHEM_CID  \
# 0                       RESULT_TYPE          NaN          NaN
# 1                      RESULT_DESCR          NaN          NaN
# 2                       RESULT_UNIT          NaN          NaN
# 3    RESULT_IS_ACTIVE_CONCENTRATION          NaN          NaN
# 4         RESULT_ATTR_CONC_MICROMOL          NaN          NaN
# ..                              ...          ...          ...
# 101                              97   47202254.0    2966254.0
# 102                              98     845167.0     647501.0
# 103                              99    3711170.0    2997527.0
# 104                             100   14740696.0    1120962.0
# 105                             101   49713840.0   24789267.0
#
#                          PUBCHEM_EXT_DATASOURCE_SMILES  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 101  C1=CC=C2C(=C1)C(=C(N2)C(=O)O)C(C3=C(C=CC(=C3)B...
# 102        CCN1C2=NC(=O)N(C(=O)C2=NC(=N1)C3=CC=CC=C3)C
# 103  CC1=CC(=NO1)NC(=O)COC(=O)C(C(C)C)NC2=C(C=C(C=C...
# 104                   COC1=CC=C(C=C1)C(=O)OC2=CN=CC=C2
# 105  CC(C)C[C@@H](C(=O)OC(C)(C)C)NC(=O)C1=C(NC=N1)C...
#
#     PUBCHEM_ACTIVITY_OUTCOME  PUBCHEM_ACTIVITY_SCORE  PUBCHEM_ACTIVITY_URL  \
# 0                        NaN                     NaN                   NaN
# 1                        NaN                     NaN                   NaN
# 2                        NaN                     NaN                   NaN
# 3                        NaN                     NaN                   NaN
# 4                        NaN                     NaN                   NaN
# ..                       ...                     ...                   ...
# 101                 Inactive                     0.0                   NaN
# 102                 Inactive                     0.0                   NaN
# 103                 Inactive                     0.0                   NaN
# 104                 Inactive                     0.0                   NaN
# 105                 Inactive                     0.0                   NaN
#
#      PUBCHEM_ASSAYDATA_COMMENT  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 101                        NaN
# 102                        NaN
# 103                        NaN
# 104                        NaN
# 105                        NaN
#
#                                              Qualifier  \
# 0                                               STRING
# 1    Activity Qualifier identifies if the resultant...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 101                                                  >
# 102                                                  >
# 103                                                  >
# 104                                                  >
# 105                                                  >
#
#                                                   IC50  ...  \
# 0                                                FLOAT  ...
# 1    The concentration at which 50 percent of the a...  ...
# 2                                           MICROMOLAR  ...
# 3                                                 TRUE  ...
# 4                                                  NaN  ...
# ..                                                 ...  ...
# 101                                              59.64  ...
# 102                                              59.64  ...
# 103                                              59.64  ...
# 104                                              59.64  ...
# 105                                              59.64  ...
#
#                                   Inhibition at 3.0 nM  \
# 0                                                FLOAT
# 1    Value of %inhibition at 3.0 nanomolar inhibito...
# 2                                              PERCENT
# 3                                                  NaN
# 4                                                0.003
# ..                                                 ...
# 101                                               -0.9
# 102                                               -1.1
# 103                                               -1.2
# 104                                               -2.2
# 105                                                1.6
#
#                                   Inhibition at 9.1 nM  \
# 0                                                FLOAT
# 1    Value of %inhibition at 9.0 nanomolar inhibito...
# 2                                              PERCENT
# 3                                                  NaN
# 4                                                0.009
# ..                                                 ...
# 101                                                0.9
# 102                                               -1.7
# 103                                               -2.3
# 104                                               -2.4
# 105                                                0.9
#
#                                  Inhibition at 27.3 nM  \
# 0                                                FLOAT
# 1    Value of %inhibition at 27.3 nanomolar inhibit...
# 2                                              PERCENT
# 3                                                  NaN
# 4                                               0.0273
# ..                                                 ...
# 101                                               -0.5
# 102                                               -1.1
# 103                                               -1.9
# 104                                               -3.1
# 105                                                  0
#
#                                  Inhibition at 81.8 nM  \
# 0                                                FLOAT
# 1    Value of %inhibition at 81.8 nanomolar inhibit...
# 2                                              PERCENT
# 3                                                  NaN
# 4                                               0.0818
# ..                                                 ...
# 101                                                1.3
# 102                                               -0.2
# 103                                               -1.5
# 104                                               -0.5
# 105                                               -0.1
#
#                                 Inhibition at 245.4 nM  \
# 0                                                FLOAT
# 1    Value of %inhibition at 245 nanomolar inhibito...
# 2                                              PERCENT
# 3                                                  NaN
# 4                                                0.245
# ..                                                 ...
# 101                                                1.9
# 102                                                1.1
# 103                                                0.4
# 104                                               -0.7
# 105                                               -0.1
#
#                                 Inhibition at 736.3 nM  \
# 0                                                FLOAT
# 1    Value of %inhibition at 736 nanomolar inhibito...
# 2                                              PERCENT
# 3                                                  NaN
# 4                                                0.736
# ..                                                 ...
# 101                                                2.5
# 102                                             -192.9
# 103                                                  0
# 104                                               -2.9
# 105                                                2.8
#
#                                   Inhibition at 2.2 uM  \
# 0                                                FLOAT
# 1    Value of %inhibition at 2.2 micromolar inhibit...
# 2                                              PERCENT
# 3                                                  NaN
# 4                                                  2.2
# ..                                                 ...
# 101                                                4.5
# 102                                             -227.1
# 103                                                3.4
# 104                                               -2.5
# 105                                                6.1
#
#                                   Inhibition at 6.6 uM  \
# 0                                                FLOAT
# 1    Value of %inhibition at 6.6 micromolar inhibit...
# 2                                              PERCENT
# 3                                                  NaN
# 4                                                  6.6
# ..                                                 ...
# 101                                               14.3
# 102                                              -47.1
# 103                                               11.5
# 104                                               -1.7
# 105                                               16.1
#
#                                  Inhibition at 19.9 uM  \
# 0                                                FLOAT
# 1    Value of %inhibition at 19.9 micromolar inhibi...
# 2                                              PERCENT
# 3                                                  NaN
# 4                                                 19.9
# ..                                                 ...
# 101                                               33.6
# 102                                               28.9
# 103                                                 22
# 104                                               -1.7
# 105                                               30.7
#
#                                  Inhibition at 59.6 uM
# 0                                                FLOAT
# 1    Value of %inhibition at 59.6 micromolar inhibi...
# 2                                              PERCENT
# 3                                                  NaN
# 4                                                 59.6
# ..                                                 ...
# 101                                               42.9
# 102                                               48.1
# 103                                               29.7
# 104                                                0.1
# 105                                                 30
#
# [106 rows x 28 columns]

# %%
df[['PUBCHEM_EXT_DATASOURCE_SMILES', 'PUBCHEM_ACTIVITY_OUTCOME']]
# Out:
#                          PUBCHEM_EXT_DATASOURCE_SMILES  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 101  C1=CC=C2C(=C1)C(=C(N2)C(=O)O)C(C3=C(C=CC(=C3)B...
# 102        CCN1C2=NC(=O)N(C(=O)C2=NC(=N1)C3=CC=CC=C3)C
# 103  CC1=CC(=NO1)NC(=O)COC(=O)C(C(C)C)NC2=C(C=C(C=C...
# 104                   COC1=CC=C(C=C1)C(=O)OC2=CN=CC=C2
# 105  CC(C)C[C@@H](C(=O)OC(C)(C)C)NC(=O)C1=C(NC=N1)C...
#
#     PUBCHEM_ACTIVITY_OUTCOME
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 101                 Inactive
# 102                 Inactive
# 103                 Inactive
# 104                 Inactive
# 105                 Inactive
#
# [106 rows x 2 columns]

# %%
import pandas as pd

df_subset = df[['PUBCHEM_EXT_DATASOURCE_SMILES', 'PUBCHEM_ACTIVITY_OUTCOME']].dropna().reset_index(drop=True)

# 컬럼 이름 변경: 'smiles'와 'label'
df_subset = df_subset.rename(columns={
    'PUBCHEM_EXT_DATASOURCE_SMILES': 'smiles',
    'PUBCHEM_ACTIVITY_OUTCOME': 'label'
})

# label 값 변환: active -> 1, inactive -> 0
df_subset['label'] = df_subset['label'].str.lower().map({'active': 1, 'inactive': 0})

# 결과 미리보기
df_subset.to_csv('3clpro.csv')
df_subset
# Out:
#                                                 smiles  label
# 0      COC1=CC=C(C=C1)C(=O)N2C3=CC4=C(C=C3N=C2SC)OCCO4      1
# 1       COC1=C(C=C(C=C1)C2CC(=NN2C(=O)CCl)C3=CC=CS3)OC      1
# 2    CCC(C)C1=CC=C(C=C1)N(C(C2=CN=CC=C2)C(=O)NC3CCC...      1
# 3    COC1=C(C=CC(=C1)C2CC(=NN2C(=O)CCl)C3=CC=CS3)OC...      1
# 4            CCC1=CC(=O)OC2=C1C=CC(=C2)OC(=O)C3=CC=CO3      1
# ..                                                 ...    ...
# 96   C1=CC=C2C(=C1)C(=C(N2)C(=O)O)C(C3=C(C=CC(=C3)B...      0
# 97         CCN1C2=NC(=O)N(C(=O)C2=NC(=N1)C3=CC=CC=C3)C      0
# 98   CC1=CC(=NO1)NC(=O)COC(=O)C(C(C)C)NC2=C(C=C(C=C...      0
# 99                    COC1=CC=C(C=C1)C(=O)OC2=CN=CC=C2      0
# 100  CC(C)C[C@@H](C(=O)OC(C)(C)C)NC(=O)C1=C(NC=N1)C...      0
#
# [101 rows x 2 columns]
