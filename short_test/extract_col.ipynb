# %%
import pandas as pd

# %%
df = pd.read_excel("/Users/song-inhyeok/Desktop/DWL-test.xlsx",  sheet_name = 'LUAD')

# %%
df
# Out:
#      IND      G1         G2  G1_Chrom  \
# 0   LUAD    CDK2     CDKN1A   12q13.2
# 1   LUAD   CCND1     CDKN1A   11q13.3
# 2   LUAD   HIF1A       TP53   14q23.2
# 3   LUAD     RB1       BRD4   13q14.2
# 4   LUAD  BCL2L1    BCL2L11  20q11.21
# 5   LUAD   CHEK1       RRM2   11q24.2
# 6   LUAD   CHEK1      RBBP8   11q24.2
# 7   LUAD    ABL1       ANK3   9q34.12
# 8   LUAD    ABL1       TLE1   9q34.12
# 9   LUAD    PTEN     RASSF2  10q23.31
# 10  LUAD   BRCA1       IQCC  17q21.31
# 11  LUAD     MET    SLC35D2      7q31
# 12  LUAD   SNAI1     PARP16  20q13.13
# 13  LUAD     MYC        RLF   8q24.21
# 14  LUAD     MYC       IQCC   8q24.21
# 15  LUAD    CDC6      SPAG5   17q21.2
# 16  LUAD    PTEN       RHOF  10q23.31
# 17  LUAD  NOTCH2     MAP2K4      1p12
# 18  LUAD   ERCC1  TNFRSF10B  19q13.32
# 19  LUAD     KIT      PLCG2      4q12
# 20  LUAD    IGF1    IGHMBP2   12q23.2
# 21  LUAD     MYC    SULT1A2   8q24.21
# 22  LUAD   CCND3      TAOK1    6p21.1
# ...

# %%
x_list = df['G1'].values.tolist()
y_list = df['G2'].values.tolist()

# %%
for x,y in zip(x_list, y_list):
    pass
