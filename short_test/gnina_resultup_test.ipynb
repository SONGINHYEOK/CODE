# %%
output_file ="/Users/song-inhyeok/Downloads/1V4S_liGAN_dock-out.txt"

# %%
f = open(output_file, 'r')
lines = f.readlines()

#client = storage.Client.from_service_account_json('./secrets/nettargets-chemdb-v1-slurm-to-storage.json')
#bucket = client.get_bucket('nettargets-discoveryweb-media-bucket')

for line in lines:
    if line[0] == '#':
        break
    spt_line = line.split(' ')
    #print(spt_line)
    
    #pose_score = spt_line[0]
    affinity = spt_line[1]
    print(affinity)
    """
    result_conf_file = spt_line[6]
    result_conf_id = result_conf_file.split('_')[-1].split('.')[0]
    print(affinity, result_conf_file, result_conf_id)
    """
# Out:
# 5.611207
# 5.574588
# 5.004752
# 5.168774
# 5.800425
# 5.400910
# 5.748724
# 4.636257
# 5.879115
# 5.659891
# 5.488260
# 4.928140
# 5.709818
# 5.298423
# 5.528354
# 4.996520
# 5.542881
# 5.164652
# 5.008246
# 5.459043
# 5.396805
# 5.992028
# 5.545772
# 4.724052
# 5.855308
# 5.134082
# 5.218188
# 5.557003
# 4.993248
# 5.753499
# 5.141173
# 5.474614
# 5.252914
# 5.408057
# 5.459323
# 4.659568
# 4.808990
# 5.447103
# 5.767498
# 5.035938
# 5.810214
# 5.178990
# 4.952042
# 5.603961
# 5.207263
# 4.980243
# 5.270579
# 5.154791
# 5.664380
# 6.165650
# 5.377752
# 4.996007
# 5.344840
# 5.163955
# 5.658957
# 5.932222
# 5.812907
# 4.925470
# 4.414684
# 5.939912
# 5.371704
# 5.705944
# 6.106132
# 5.382934
# 5.720799
# 5.050889
# 5.518820
# 5.506943
# 5.096019
# 5.807966
# 5.457348
# 5.579500
# 5.870574
# 5.793335
# 5.907110
# 5.542414
# 5.745279
# 6.058254
# 5.319313
# 5.769655
# 5.333361
# 5.699683
# 5.285038
# 5.342032
# 5.789019
# 5.662795
# 5.514939
# 6.125633
# 5.027692
# 5.605237
# ...
