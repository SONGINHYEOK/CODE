# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/song-inhyeok/Downloads/User Spreadsheet 11 2022-07-08.txt', sep='\t')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 633 entries, 0 to 632
# Columns: 167 entries, Structure to Unnamed: 166
# dtypes: float64(152), object(15)
# memory usage: 826.0+ KB

# %%
df.columns.tolist()
# Out:
# ['Structure',
#  'Molecular Weight',
#  'No. of Hydrogen Bond Donors',
#  'No. of Hydrogen Bond Acceptors',
#  'TPSA',
#  'No. of Rotatable Bonds',
#  'C Ratio',
#  'N Ratio',
#  'NO Ratio',
#  'Hetero Ratio',
#  'Halogen Ratio',
#  'Number of Rings',
#  'Number of Aromatic Rings',
#  'Number of Rings (size 3)',
#  'Number of Rings (size 4)',
#  'Number of Rings (size 5)',
#  'Number of Rings (size 6)',
#  'P-gp substrate probability (Final)',
#  'P-gp substrate probability (RI)',
#  'P-gp good substrate probability (Final)',
#  'P-gp good substrate probability (RI)',
#  'CYP3A4  Inhibitor (IC50 < 10 uM) (Final)',
#  'CYP3A4  Inhibitor (IC50 < 10 uM) (RI)',
#  'CYP2D6  Inhibitor (IC50 < 10 uM) (Final)',
#  'CYP2D6  Inhibitor (IC50 < 10 uM) (RI)',
#  'CYP2C9  Inhibitor (IC50 < 10 uM) (Final)',
#  'CYP2C9  Inhibitor (IC50 < 10 uM) (RI)',
#  'CYP2C19  Inhibitor (IC50 < 10 uM) (Final)',
#  'CYP2C19  Inhibitor (IC50 < 10 uM) (RI)',
#  'CYP1A2  Inhibitor (IC50 < 10 uM) (Final)',
# ...

# %%
df = df.drop(['Unnamed: 166', 'Structure'], axis=1)

# %%
df
# Out:
#      Molecular Weight  No. of Hydrogen Bond Donors  \
# 0           302.33196                          4.0
# 1           353.37874                          NaN
# 2                 NaN                          NaN
# 3           336.39492                          NaN
# 4                 NaN                          NaN
# ..                ...                          ...
# 628         315.37044                          3.0
# 629         358.37292                          2.0
# 630         363.41662                          2.0
# 631         312.36308                          NaN
# 632         309.36248                          1.0
#
#      No. of Hydrogen Bond Acceptors    TPSA  No. of Rotatable Bonds   C Ratio  \
# 0                               8.0  117.46                     4.0  0.636364
# 1                               9.0  100.27                     4.0       NaN
# 2                               NaN  144.85                     3.0  0.545455
# ...

# %%
df2 = pd.read_csv('/Users/song-inhyeok/Desktop/admet_data/ADMET_list_1.csv', header=None, names=['id','smiles'])

# %%
df2
# Out:
#             id                                             smiles
# 0    131899694         N=c1nc(C2CCN(Cc3c[nH]nc3C(=O)O)CC2)cc[nH]1
# 1    131899718       Cn1ncc2c(N3CCN(CC(=O)O)CC3)nc(-c3cccnc3)nc21
# 2      8629175          CCNC(=O)C1OC(n2cnc3c(=N)[nH]cnc32)C(O)C1O
# 3    131892443         Cc1c(C(=O)NCCSc2c[nH]nn2)sc2[nH]cnc(=O)c12
# 4    136244238              COc1cccc(-c2ccnc3nc(-c4ccncc4)nn23)c1
# ..         ...                                                ...
# 628  131893908           N=c1[nH]cccc1CN1CCCC(c2ccn(CC(=O)O)n2)C1
# 629  131894108         O=C1COc2ccc(S(=O)(=O)NCc3cccn4nccc34)cc2N1
# 630  131894125  CC(=O)N1CCc2c([nH]c(-c3cccnc3)nc2=NCCc2c[nH]cn...
# 631  113433789          CN(Cc1ccc2cnccc2c1)C(=O)C1(C)CC(C(=O)O)C1
# 632  114047793        O=C1CC(CC(=O)N2CC=C(c3ccnc4[nH]ccc34)CC2)C1
#
# [633 rows x 2 columns]

# %%
df['id'] = df2['id']

# %%
df
# Out:
#      Molecular Weight  No. of Hydrogen Bond Donors  \
# 0           302.33196                          4.0
# 1           353.37874                          NaN
# 2                 NaN                          NaN
# 3           336.39492                          NaN
# 4                 NaN                          NaN
# ..                ...                          ...
# 628         315.37044                          3.0
# 629         358.37292                          2.0
# 630         363.41662                          2.0
# 631         312.36308                          NaN
# 632         309.36248                          1.0
#
#      No. of Hydrogen Bond Acceptors    TPSA  No. of Rotatable Bonds   C Ratio  \
# 0                               8.0  117.46                     4.0  0.636364
# 1                               9.0  100.27                     4.0       NaN
# 2                               NaN  144.85                     3.0  0.545455
# ...

# %%
col_dict = {}

# %%
col_list = df.columns.tolist()

# %%
len(col_list)
# Out:
# 166

# %%
for i, name in enumerate(col_list):
    col_dict[i]=name

# %%
col_dict
# Out:
# {0: 'Molecular Weight',
#  1: 'No. of Hydrogen Bond Donors',
#  2: 'No. of Hydrogen Bond Acceptors',
#  3: 'TPSA',
#  4: 'No. of Rotatable Bonds',
#  5: 'C Ratio',
#  6: 'N Ratio',
#  7: 'NO Ratio',
#  8: 'Hetero Ratio',
#  9: 'Halogen Ratio',
#  10: 'Number of Rings',
#  11: 'Number of Aromatic Rings',
#  12: 'Number of Rings (size 3)',
#  13: 'Number of Rings (size 4)',
#  14: 'Number of Rings (size 5)',
#  15: 'Number of Rings (size 6)',
#  16: 'P-gp substrate probability (Final)',
#  17: 'P-gp substrate probability (RI)',
#  18: 'P-gp good substrate probability (Final)',
#  19: 'P-gp good substrate probability (RI)',
#  20: 'CYP3A4  Inhibitor (IC50 < 10 uM) (Final)',
#  21: 'CYP3A4  Inhibitor (IC50 < 10 uM) (RI)',
#  22: 'CYP2D6  Inhibitor (IC50 < 10 uM) (Final)',
#  23: 'CYP2D6  Inhibitor (IC50 < 10 uM) (RI)',
#  24: 'CYP2C9  Inhibitor (IC50 < 10 uM) (Final)',
#  25: 'CYP2C9  Inhibitor (IC50 < 10 uM) (RI)',
#  26: 'CYP2C19  Inhibitor (IC50 < 10 uM) (Final)',
# ...

# %%
df3 = pd.DataFrame([col_dict])

# %%
df3.T.to_csv('/Users/song-inhyeok/Desktop/admet_data/ADMET_col.csv')

# %%
df.to_csv('/Users/song-inhyeok/Desktop/admet_data/sample_1.csv')

# %%
id_list = df['id'].tolist()
        
for i in id_list:        
   # molecule = self.session.query(Molecule).filter(Molecule.id==i).first() 
    
    mw = df.loc[df['id']==i].values[0][0]
    logp = df.loc[df['id']==i].values[0][58]
    tpsa = df.loc[df['id']==i].values[0][3]
    h_donors = df.loc[df['id']==i].values[0][1]
    h_acceptors = df.loc[df['id']==i].values[0][2]
    rot_bonds = df.loc[df['id']==i].values[0][4]
    rings = df.loc[df['id']==i].values[0][10]
    #print(mw, logp, tpsa, h_don, h_acc, rot, ring)
    
    #absorp
    a = df.loc[df['id']==i].values[0][91]
    b = df.loc[df['id']==i].values[0][92]
    bo = df.loc[df['id']==i].values[0][93]
    l = df.loc[df['id']==i].values[0][94]
    s = df.loc[df['id']==i].values[0][95]
    e = df.loc[df['id']==i].values[0][96]
    mcgowanvolume = df.loc[df['id']==i].values[0][97]
    #print(a, b, bo, l, s, e, mcgowanvolume)
    
    abs_oral_dose_02mg = df.loc[df['id']==i].values[0][146]
    abs_oral_dose_1mg = df.loc[df['id']==i].values[0][147]
    abs_oral_dose_5mg = df.loc[df['id']==i].values[0][148]
    abs_oral_dose_20mg = df.loc[df['id']==i].values[0][149]
    abs_oral_dose_50mg = df.loc[df['id']==i].values[0][150]
    abs_oral_dose_100mg = df.loc[df['id']==i].values[0][151]
    abs_oral_dose_500mg = df.loc[df['id']==i].values[0][152]
    pe = df.loc[df['id']==i].values[0][108]
    ka = df.loc[df['id']==i].values[0][109]
    maxhia = df.loc[df['id']==i].values[0][110]
    #print(abs_oral_dose_02mg, abs_oral_dose_1mg,abs_oral_dose_5mg, abs_oral_dose_20mg,  abs_oral_dose_50mg ,  abs_oral_dose_100mg,  abs_oral_dose_500mg, pe, ka, maxhia)
    
    pecaco2_ph65_0rpm = df.loc[df['id']==i].values[0][140]
    pecaco2_ph65_500rpm = df.loc[df['id']==i].values[0][141] 
    pecaco2_ph74_0rpm = df.loc[df['id']==i].values[0][142]
    pecaco2_ph74_500rpm = df.loc[df['id']==i].values[0][143]  
    pecaco2_ph80_0rpm = df.loc[df['id']==i].values[0][144]
    pecaco2_ph80_500rpm = df.loc[df['id']==i].values[0][145]
    mrdd  = df.loc[df['id']==i].values[0][47]
    mrddclass = df.loc[df['id']==i].values[0][48]
    

    #distribution
    logps = df.loc[df['id']==i].values[0][87]
    logbb = df.loc[df['id']==i].values[0][88]
    fu_brain = df.loc[df['id']==i].values[0][89]
    bbb_eq_rate = df.loc[df['id']==i].values[0][90] 
    _ppb = df.loc[df['id']==i].values[0][123] 
    _ppb_ri = df.loc[df['id']==i].values[0][124]
    logka_hsa = df.loc[df['id']==i].values[0][125]
    logka_hsa_ri = df.loc[df['id']==i].values[0][126] 
    vss = df.loc[df['id']==i].values[0][40]
    actr_asbt_substrate = df.loc[df['id']==i].values[0][102]
    actr_pept1_substrate = df.loc[df['id']==i].values[0][103]
    actr_mct1_substrate = df.loc[df['id']==i].values[0][104]
    actr_amino_acid_transport = df.loc[df['id']==i].values[0][105]
    actr_other_transport = df.loc[df['id']==i].values[0][106]


    #metabolism
    _pgp_s = df.loc[df['id']==i].values[0][16]
    _pgp_s_ri = df.loc[df['id']==i].values[0][17]
    _pgp_s_good = df.loc[df['id']==i].values[0][18]
    _pgp_s_good_ri = df.loc[df['id']==i].values[0][19]
    _pgp_i = df.loc[df['id']==i].values[0][128]
    _pgp_i_ri = df.loc[df['id']==i].values[0][129]
    _pgp_i_good = df.loc[df['id']==i].values[0][130]
    _pgp_i_good_ri = df.loc[df['id']==i].values[0][131]
    _cyp3a4_i_10 = df.loc[df['id']==i].values[0][20]
    _cyp3a4_i_10_ri = df.loc[df['id']==i].values[0][21]
    _cyp2d6_i_10 = df.loc[df['id']==i].values[0][22]
    _cyp2d6_i_10_ri = df.loc[df['id']==i].values[0][23]
    _cyp2c9_i_10 = df.loc[df['id']==i].values[0][24]
    _cyp2c9_i_10_ri = df.loc[df['id']==i].values[0][25]
    _cyp2c19_i_10 = df.loc[df['id']==i].values[0][26]
    _cyp2c19_i_10_ri = df.loc[df['id']==i].values[0][27]
    _cyp1a2_i_10 = df.loc[df['id']==i].values[0][28]
    _cyp1a2_i_10_ri =df.loc[df['id']==i].values[0][29]
    _cyp3a4_i_50 = df.loc[df['id']==i].values[0][30]
    _cyp3a4_i_50_ri = df.loc[df['id']==i].values[0][31]
    _cyp2d6_i_50 = df.loc[df['id']==i].values[0][32]
    _cyp2d6_i_50_ri = df.loc[df['id']==i].values[0][33]
    _cyp2c9_i_50 = df.loc[df['id']==i].values[0][34]
    _cyp2c9_i_50_ri = df.loc[df['id']==i].values[0][35]
    _cyp2c19_i_50 = df.loc[df['id']==i].values[0][36]
    _cyp2c19_i_50_ri = df.loc[df['id']==i].values[0][37]
    _cyp1a2_i_50 = df.loc[df['id']==i].values[0][38]
    _cyp1a2_i_50_ri = df.loc[df['id']==i].values[0][39]
    _cyp3a4_s = df.loc[df['id']==i].values[0][111]
    _cyp3a4_s_ri = df.loc[df['id']==i].values[0][112]
    _cyp2d6_s = df.loc[df['id']==i].values[0][113]
    _cyp2d6_s_ri = df.loc[df['id']==i].values[0][114]
    _cyp2c9_s = df.loc[df['id']==i].values[0][115]
    _cyp2c9_s_ri = df.loc[df['id']==i].values[0][116]
    _cyp2c19_s = df.loc[df['id']==i].values[0][117]
    _cyp2c19_s_ri = df.loc[df['id']==i].values[0][118]
    _cyp1a2_s = df.loc[df['id']==i].values[0][119]
    _cyp1a2_s_ri = df.loc[df['id']==i].values[0][120]

    #toxicity
    _ld50_mouse_ip = df.loc[df['id']==i].values[0][71]
    _ld50_mouse_ip_ri = df.loc[df['id']==i].values[0][72]
    _ld50_mouse_or = df.loc[df['id']==i].values[0][73]
    _ld50_mouse_or_ri = df.loc[df['id']==i].values[0][74]
    _ld50_mouse_iv = df.loc[df['id']==i].values[0][75]
    _ld50_mouse_iv_ri = df.loc[df['id']==i].values[0][76]
    _ld50_mouse_sc = df.loc[df['id']==i].values[0][77]
    _ld50_mouse_sc_ri = df.loc[df['id']==i].values[0][78]
    _ld50_rat_ip = df.loc[df['id']==i].values[0][79]
    _ld50_rat_ip_ri = df.loc[df['id']==i].values[0][80]
    _ld50_rat_or = df.loc[df['id']==i].values[0][81]
    _ld50_rat_or_ri = df.loc[df['id']==i].values[0][82]
    _lc50_ppromelas = df.loc[df['id']==i].values[0][98]
    _lc50_ppromelas_ri = df.loc[df['id']==i].values[0][99]
    _lc50_dmagna = df.loc[df['id']==i].values[0][100]
    _lc50_dmagna_ri = df.loc[df['id']==i].values[0][101]
    _igc50_tpyriformis = df.loc[df['id']==i].values[0][137]
    _igc50_tpyriformis_ri = df.loc[df['id']==i].values[0][138]
    _ames = df.loc[df['id']==i].values[0][121]
    _ames_ri = df.loc[df['id']==i].values[0][122]
    _logrba_3 = df.loc[df['id']==i].values[0][83]
    _logrba_3_ri = df.loc[df['id']==i].values[0][84]
    _logrba_0 = df.loc[df['id']==i].values[0][85]
    _logrba_0_ri = df.loc[df['id']==i].values[0][86]
    probability_of_he_on_blood = df.loc[df['id']==i].values[0][41]
    probability_of_he_on_cardiovascular_system = df.loc[df['id']==i].values[0][42]
    probability_of_he_on_gastrointestinal_system = df.loc[df['id']==i].values[0][43]
    probability_of_he_on_kidney = df.loc[df['id']==i].values[0][44] 
    probability_of_he_on_liver = df.loc[df['id']==i].values[0][45]
    probability_of_he_on_lungs = df.loc[df['id']==i].values[0][46]
    _herg = df.loc[df['id']==i].values[0][69]
    _herg_ri = df.loc[df['id']==i].values[0][70]
    eye_irritation = df.loc[df['id']==i].values[0][107]
    skin_irritation = df.loc[df['id']==i].values[0][127]
            
    #leadlike_category
    mw_class_val = df.loc[df['id']==i].values[0][154]
    logp_class_val = df.loc[df['id']==i].values[0][153]
    solubility_classs_val = df.loc[df['id']==i].values[0][159]
    perme_val = df.loc[df['id']==i].values[0][160]
    hia_val = df.loc[df['id']==i].values[0][161]
    meta_val = df.loc[df['id']==i].values[0][162]
    ames_val =df.loc[df['id']==i].values[0][163]
    herg_val =df.loc[df['id']==i].values[0][164]
    print( mw_class_val, logp_class_val, solubility_classs_val, perme_val, hia_val, meta_val, ames_val, herg_val)
    
    """
    mw_class = self.session.query(Mw_class_type).filter(Mw_class_type.name==mw_class_val).first()
    logp_class = self.session.query(Logp_class_type).filter(Logp_class_type.name==logp_class_val).first()
    solubility_classs= self.session.query(Solubility_class_type).filter(Solubility_class_type.name==solubility_classs_val).first()
    permeability_class= self.session.query(Permeability_class_type).filter(Permeability_class_type.name==perme_val).first()
    hia_class = self.session.query(Hia_class_type).filter(Hia_class_type.name==hia_val).first()
    meta_class = self.session.query(Stability_class_type).filter(Stability_class_type.name==meta_val).first()
    ames_class = self.session.query(Ames_class_type).filter(Ames_class_type.name==ames_val).first()
    herg_class = self.session.query(Herg_class_type).filter(Herg_class_type.name==herg_val).first()


    #upload_process
    #physchem
    physchem = None
    physchem = self.session.query(Physchem).filter(Physchem.id==molecule.id).first()
    
    if physchem == None :
            physchem = Physchem(mw, logp, tpsa, h_donors, h_acceptors, rot_bonds, rings)
            physchem.molecule = molecule
            self.session.add(physchem)
            print('upload_physchem')
    self.session.commit() 
    
    #absorption
    absorption = None
    absorption = self.session.query(Absorption).filter(Absorption.id==molecule.id).first()
    
    if absorption == None :
            absorption = Absorption(a,b,bo,l,s,e, mcgowanvolume, abs_oral_dose_02mg, abs_oral_dose_1mg,abs_oral_dose_5mg, abs_oral_dose_20mg,  abs_oral_dose_50mg ,  abs_oral_dose_100mg,  abs_oral_dose_500mg , pe, ka, maxhia, pecaco2_ph65_0rpm, pecaco2_ph65_500rpm ,  pecaco2_ph74_0rpm , pecaco2_ph74_500rpm,  pecaco2_ph80_0rpm, pecaco2_ph80_500rpm,  mrdd ,  mrddclass)
            absorption.molecule = molecule
            self.session.add(absorption)
            print('upload_absorption')
    self.session.commit() 
    
    
    #distribution 
    distribution = None
    distribution = self.session.query(Distribution).filter(Distribution.id==molecule.id).first()
    
    if distribution == None :
            distribution = Distribution(logps, logbb,fu_brain,bbb_eq_rate, _ppb, _ppb_ri,logka_hsa,logka_hsa_ri, vss,actr_asbt_substrate, actr_pept1_substrate, actr_mct1_substrate,actr_amino_acid_transport,actr_other_transport)
            distribution.molecule = molecule
            self.session.add(distribution)
            print('upload_distribution')
    self.session.commit() 
    
    #metabolism
    metabolism = None
    metabolism = self.session.query(Metabolism).filter(Metabolism.id==molecule.id).first()
    
    if metabolism == None :
            metabolism = Metabolism(_pgp_s, _pgp_s_ri, _pgp_s_good, _pgp_s_good_ri, _pgp_i, _pgp_i_ri, _pgp_i_good, _pgp_i_good_ri, _cyp3a4_i_10, _cyp3a4_i_10_ri, _cyp2d6_i_10, _cyp2d6_i_10_ri, _cyp2c9_i_10, _cyp2c9_i_10_ri, _cyp2c19_i_10, _cyp2c19_i_10_ri,_cyp1a2_i_10, _cyp1a2_i_10_ri, _cyp3a4_i_50,_cyp3a4_i_50_ri, _cyp2d6_i_50,_cyp2d6_i_50_ri, _cyp2c9_i_50, _cyp2c9_i_50_ri, _cyp2c19_i_50, _cyp2c19_i_50_ri,_cyp1a2_i_50,_cyp1a2_i_50_ri, _cyp3a4_s, _cyp3a4_s_ri, _cyp2d6_s, _cyp2d6_s_ri, _cyp2c9_s, 
                                    _cyp2c9_s_ri, _cyp2c19_s, _cyp2c19_s_ri, _cyp1a2_s, _cyp1a2_s_ri)
            metabolism.molecule = molecule
            self.session.add(metabolism)
            print('upload_metabolism')
    self.session.commit() 
    
    #toxicity
    toxicity = None
    toxicity = self.session.query(Toxicity).filter(Toxicity.id==molecule.id).first()
    
    if toxicity == None :
            toxicity = Toxicity( _ld50_mouse_ip, _ld50_mouse_ip_ri, _ld50_mouse_or, _ld50_mouse_or_ri, _ld50_mouse_iv, _ld50_mouse_iv_ri,  _ld50_mouse_sc,  _ld50_mouse_sc_ri,   _ld50_rat_ip,   _ld50_rat_ip_ri,  _ld50_rat_or,  _ld50_rat_or_ri,  _lc50_ppromelas,  _lc50_ppromelas_ri,  _lc50_dmagna,  _lc50_dmagna_ri,  _igc50_tpyriformis,  _igc50_tpyriformis_ri,  _ames,  _ames_ri,  _logrba_3,  _logrba_3_ri, _logrba_0,  _logrba_0_ri, probability_of_he_on_blood,  probability_of_he_on_cardiovascular_system, 
                                probability_of_he_on_gastrointestinal_system,  probability_of_he_on_kidney,  probability_of_he_on_liver,  probability_of_he_on_lungs,  _herg,  _herg_ri,  eye_irritation,    skin_irritation)
            toxicity.molecule = molecule
            self.session.add(toxicity)
            print('upload_toxicity')
    self.session.commit() 
    
    #leadlike_category
    leadlike_category = None
    leadlike_category = self.session.query(Leadlike_category).filter(Leadlike_category.id==molecule.id).first()
    
    if leadlike_category == None :
            leadlike_category = Leadlike_category(mw, logp, tpsa, h_donors, h_acceptors, rot_bonds, rings)
            leadlike_category.molecule = molecule
            self.session.add(leadlike_category)
            print('upload_leadlike_category')
    self.session.commit() 
"""
# Out:
# None None None None None None None None
# None None None None None None None None
# None None None None None None None None
# None None None None None None None None
# None None None None None None None None
# None None None None None None None None
# None None None None None None None None
# None None None None None None None None
# None None None None None None None None
# None None None None None None None None
# None None None None None None None None
# None None None None None None None None
# None None None None None None None None
# None None None None None None None None
# None None None None None None None None
# None None None None None None None None
# None None None None None None None None
# None None None None None None None None
# None None None None None None None None
# None None None None None None None None
# None None None None None None None None
# None None None None None None None None
# None None None None None None None None
# ...

# %%
df.loc[df['id']==114790755].values[0][152]
# Out:
# 52.308789279804856

# %%
em
# Out:
#    Molecular Weight No. of Hydrogen Bond Donors  \
# 55             None                        None
#
#    No. of Hydrogen Bond Acceptors  TPSA No. of Rotatable Bonds C Ratio  \
# 55                           None  None                   None    None
#
#    N Ratio NO Ratio Hetero Ratio Halogen Ratio  ... H-Acceptors (Category)  \
# 55    None     None         None          None  ...                   Good
#
#    Rotatable bonds (Category) Rings (Category) Solubility (Category)  \
# 55                       None             None               Soluble
#
#    Caco-2 permeability (Category)   HIA (Category)  \
# 55           Moderately Permeable  Highly absorbed
#
#    Metabolic stability (Category) Ames test (Category)  \
# 55                      Undefined            Undefined
#
#    hERG inhibition (Category)         id
# 55                       None  114790755
#
# [1 rows x 166 columns]

# %%
em.to_csv('/Users/song-inhyeok/Desktop/admet_data/error_test.csv')

# %%
df.loc[df['id']==114790755]['LogP (Category)']
# Out:
# 55    Optimal
# Name: LogP (Category), dtype: object
