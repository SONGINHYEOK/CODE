# %%
import psutil

for process in psutil.process_iter():
    print(process.name() + "\t"+str(process.pid))
# Out:
# kernel_task	0
# launchd	1
# logd	303
# UserEventAgent	304
# uninstalld	306
# fseventsd	307
# mediaremoted	308
# systemstats	311
# configd	312
# endpointsecurity	313
# powerd	314
# IOMFB_bics_daemo	315
# remoted	318
# keybagd	320
# softwareupdated	322
# watchdogd	324
# mds	328
# iconservicesd	329
# kernelmanagerd	330
# diskarbitrationd	331
# coreduetd	334
# syslogd	335
# thermalmonitord	338
# opendirectoryd	339
# apsd	340
# launchservicesd	341
# timed	342
# usbmuxd	343
# securityd	344
# auditd	345
# locationd	347
# autofsd	349
# dasd	350
# distnoted	352
# AppleCredentialM	353
# PerfPowerService	354
# logind	356
# revisiond	357
# KernelEventAgent	358
# bluetoothd	360
# notifyd	361
# sandboxd	362
# corebrightnessd	363
# AirPlayXPCHelper	364
# com.apple.cmio.r	365
# cfprefsd	366
# syspolicyd	367
# logd_helper	368
# WindowServer	369
# tccd	370
# aslmanager	371
# loginwindow	372
# contextstored	373
# PowerUIAgent	375
# authd	383
# coreservicesd	384
# airportd	385
# trustd	386
# ...

# %%
import time
 
def do_something():
    print('Sleeping 1 seconds')
    time.sleep(1)
    print('Done Sleeping...')
 
if __name__ == '__main__':
    start = time.perf_counter()
    for _ in range(10):
        do_something()
    finish = time.perf_counter()
    
    print(f'Finished in {round(finish-start, 2)} second(s)')
# Out:
# Sleeping 1 seconds
# Done Sleeping...
# Sleeping 1 seconds
# Done Sleeping...
# Sleeping 1 seconds
# Done Sleeping...
# Sleeping 1 seconds
# Done Sleeping...
# Sleeping 1 seconds
# Done Sleeping...
# Sleeping 1 seconds
# Done Sleeping...
# Sleeping 1 seconds
# Done Sleeping...
# Sleeping 1 seconds
# Done Sleeping...
# Sleeping 1 seconds
# Done Sleeping...
# Sleeping 1 seconds
# Done Sleeping...
# Finished in 10.04 second(s)

# %%
import time
import threading
import os
base_path = '/opt/homebrew/Caskroom/miniforge/base/bin/python3'
input_path  = "/Users/song-inhyeok/Documents/ZINC20_cr_project/ZINC20_data/1"
output_path = "/Users/song-inhyeok/Documents/ZINC20_cr_project/ZINC20_data/1_out"
#file_list = os.listdir()
file_list = os.listdir(input_path)
print(file_list)


def do_something():
    for name in file_list:
        os.system(base_path+ ' '+ )
    
if __name__ == '__main__':
    start = time.perf_counter()
    threads = []
    for _ in range(len(file_list)):
        t = threading.Thread(target=do_something)
        t.start()
        threads.append(t)
        
    for thread in threads:
        thread.join()
    finish = time.perf_counter()
 
    print(f'Finished in {round(finish-start, 2)} second(s)')
# Out:
# ['ZINC_1_640.csv', 'ZINC_1_898.csv', 'ZINC_1_3919.csv', 'ZINC_1_8694.csv', 'ZINC_1_6861.csv', 'ZINC_1_1868.csv', 'ZINC_1_4910.csv', 'ZINC_1_126.csv', 'ZINC_1_4904.csv', 'ZINC_1_132.csv', 'ZINC_1_8858.csv', 'ZINC_1_8680.csv', 'ZINC_1_6875.csv', 'ZINC_1_654.csv', 'ZINC_1_8870.csv', 'ZINC_1_6685.csv', 'ZINC_1_4092.csv', 'ZINC_1_3925.csv', 'ZINC_1_2385.csv', 'ZINC_1_1854.csv', 'ZINC_1_1840.csv', 'ZINC_1_1698.csv', 'ZINC_1_2391.csv', 'ZINC_1_4938.csv', 'ZINC_1_668.csv', 'ZINC_1_4086.csv', 'ZINC_1_3931.csv', 'ZINC_1_5398.csv', 'ZINC_1_8864.csv', 'ZINC_1_6691.csv', 'ZINC_1_6849.csv', 'ZINC_1_8657.csv', 'ZINC_1_7564.csv', 'ZINC_1_1115.csv', 'ZINC_1_9549.csv', 'ZINC_1_5373.csv', 'ZINC_1_3702.csv', 'ZINC_1_683.csv', 'ZINC_1_3064.csv', 'ZINC_1_5415.csv', 'ZINC_1_1673.csv', 'ZINC_1_8131.csv', 'ZINC_1_7202.csv', 'ZINC_1_6108.csv', 'ZINC_1_1667.csv', 'ZINC_1_8125.csv', 'ZINC_1_7216.csv', 'ZINC_1_3070.csv', 'ZINC_1_5401.csv', 'ZINC_1_5367.csv', 'ZINC_1_2408.csv', 'ZINC_1_697.csv', 'ZINC_1_3716.csv'
# ...
