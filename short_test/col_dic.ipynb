# %%
import pandas as pd

# %%
ori = "/Users/song-inhyeok/Desktop/admet_data/chembl_data/result_file/chembl_6.csv"

# %%
df = pd.read_csv(ori)

# %%
col_dic = {}
for i,name in enumerate(df.columns.tolist()):
    col_dic[i]= name

# %%
col_dic
# Out:
# {0: 'LogP',
#  1: 'MW',
#  2: 'H-Donors',
#  3: 'H-Acceptors',
#  4: 'Rot. Bonds',
#  5: 'Rings',
#  6: 'Lipinski',
#  7: 'Lead-like',
#  8: 'Solubility',
#  9: 'P-gp Substrates',
#  10: 'CYP1A2 Inhibitor',
#  11: 'CYP2C9 Inhibitor',
#  12: 'CYP2C19 Inhibitor',
#  13: 'CYP2D6 Inhibitor',
#  14: 'CYP3A4 Inhibitor',
#  15: 'Ames',
#  16: 'hERG',
#  17: 'Caco-2',
#  18: 'PPB',
#  19: 'CNS',
#  20: 'HIA',
#  21: 'Metabolic Stability',
#  22: 'Probability of positive Ames test|Probability of positive Ames test',
#  23: 'Probability of positive Ames test|RI',
#  24: 'P-gp inhibitor probability|P-gp inhibitor probability',
#  25: 'P-gp inhibitor probability|RI',
#  26: 'P-gp good inhibitor probability|P-gp good inhibitor probability',
#  27: 'P-gp good inhibitor probability|RI',
#  28: 'MRDD (mg/kg/day)',
#  29: 'Probability (MRDD < 3 mg/kg/day)',
#  30: 'LogS0|LogS0',
#  31: 'LogS0|RI',
#  32: 'LogPS',
#  33: 'LogBB',
#  34: 'Fraction unbound in brain (fu, brain)',
#  35: 'Log(PS*fu, brain)',
#  36: 'CYP3A4  Substrate|CYP3A4  Substrate',
#  37: 'CYP3A4  Substrate|RI',
#  38: 'CYP2D6  Substrate|CYP2D6  Substrate',
#  39: 'CYP2D6  Substrate|RI',
#  40: 'CYP2C9  Substrate|CYP2C9  Substrate',
#  41: 'CYP2C9  Substrate|RI',
#  42: 'CYP2C19  Substrate|CYP2C19  Substrate',
#  43: 'CYP2C19  Substrate|RI',
#  44: 'CYP1A2  Substrate|CYP1A2  Substrate',
#  45: 'CYP1A2  Substrate|RI',
#  46: 'pKa(Acid)|pKa',
#  47: 'pKa(Acid)|Conf. limits',
#  48: 'pKa(Acid)|AtomNo',
#  49: 'pKa(Base)|pKa',
#  50: 'pKa(Base)|Conf. limits',
#  51: 'pKa(Base)|AtomNo',
#  52: 'Isoelectric point',
#  53: 'CYP2C9 Regioselectivity|Score',
#  54: 'CYP2C9 Regioselectivity|Reliability',
#  55: 'CYP2C9 Regioselectivity|AtomNo',
#  56: 'CYP2C9 Regioselectivity|ReactionType',
#  57: 'Molecular Weight',
#  58: 'No. of Hydrogen Bond Donors',
#  59: 'No. of Hydrogen Bond Acceptors',
#  60: 'TPSA',
#  61: 'No. of Rotatable Bonds',
#  62: 'C Ratio',
#  63: 'N Ratio',
#  64: 'NO Ratio',
#  65: 'Hetero Ratio',
#  66: 'Halogen Ratio',
#  67: 'Number of Rings',
#  68: 'Number of Aromatic Rings',
#  69: 'Number of Rings (size 3)',
#  70: 'Number of Rings (size 4)',
#  71: 'Number of Rings (size 5)',
#  72: 'Number of Rings (size 6)',
#  73: 'Dielectric Constant',
#  74: 'Parachor',
#  75: 'Index of Refraction',
#  76: 'Surface Tension',
#  77: 'Density',
#  78: 'Polarizability',
#  79: 'Molar Volume',
#  80: 'Molar Refractivity',
#  81: 'Bioavailability (%) (Dose, mg = 0.20)',
#  82: 'Bioavailability (%) (Dose, mg = 1.00)',
#  83: 'Bioavailability (%) (Dose, mg = 5.00)',
#  84: 'Bioavailability (%) (Dose, mg = 20.00)',
#  85: 'Bioavailability (%) (Dose, mg = 50.00)',
#  86: 'Bioavailability (%) (Dose, mg = 100.00)',
#  87: 'Bioavailability (%) (Dose, mg = 500.00)',
#  88: 'CYP1A2 Regioselectivity|Score',
#  89: 'CYP1A2 Regioselectivity|Reliability',
#  90: 'CYP1A2 Regioselectivity|AtomNo',
#  91: 'CYP1A2 Regioselectivity|ReactionType',
#  92: 'hERG Inhibitor (Ki < 10 uM) GALAS probability|hERG Inhibitor (Ki < 10 uM) GALAS probability',
#  93: 'hERG Inhibitor (Ki < 10 uM) GALAS probability|RI',
#  94: 'hERG Inhibitor (Ki < 10 uM) PhysChem probability',
#  95: 'LogP (1)|LogP',
#  96: 'LogP (1)|RI',
#  97: 'LogS (pH = 7.40)',
#  98: 'LogSw|LogSw',
#  99: 'LogSw|pH',
#  100: 'pKa(Acid) (1)|pKa',
#  101: 'pKa(Acid) (1)|Conf. limits',
#  102: 'pKa(Acid) (1)|AtomNo',
#  103: 'pKa(Base) (1)|pKa',
#  104: 'pKa(Base) (1)|Conf. limits',
#  105: 'pKa(Base) (1)|AtomNo',
#  106: 'Isoelectric point (1)',
#  107: 'P-gp substrate probability|P-gp substrate probability',
#  108: 'P-gp substrate probability|RI',
#  109: 'P-gp good substrate probability|P-gp good substrate probability',
#  110: 'P-gp good substrate probability|RI',
#  111: 'CYP2D6 Regioselectivity|Score',
#  112: 'CYP2D6 Regioselectivity|Reliability',
#  113: 'CYP2D6 Regioselectivity|AtomNo',
#  114: 'CYP2D6 Regioselectivity|ReactionType',
#  115: 'LogP (2)',
#  116: 'CYP3A4 Regioselectivity|Score',
#  117: 'CYP3A4 Regioselectivity|Reliability',
#  118: 'CYP3A4 Regioselectivity|AtomNo',
#  119: 'CYP3A4 Regioselectivity|ReactionType',
#  120: 'Enthalpy of Vaporization',
#  121: 'Flash Point',
#  122: 'CYP3A4  Inhibitor (IC50 < 10 uM)|CYP3A4  Inhibitor (IC50 < 10 uM)',
#  123: 'CYP3A4  Inhibitor (IC50 < 10 uM)|RI',
#  124: 'CYP2D6  Inhibitor (IC50 < 10 uM)|CYP2D6  Inhibitor (IC50 < 10 uM)',
#  125: 'CYP2D6  Inhibitor (IC50 < 10 uM)|RI',
#  126: 'CYP2C9  Inhibitor (IC50 < 10 uM)|CYP2C9  Inhibitor (IC50 < 10 uM)',
#  127: 'CYP2C9  Inhibitor (IC50 < 10 uM)|RI',
#  128: 'CYP2C19  Inhibitor (IC50 < 10 uM)|CYP2C19  Inhibitor (IC50 < 10 uM)',
#  129: 'CYP2C19  Inhibitor (IC50 < 10 uM)|RI',
#  130: 'CYP1A2  Inhibitor (IC50 < 10 uM)|CYP1A2  Inhibitor (IC50 < 10 uM)',
#  131: 'CYP1A2  Inhibitor (IC50 < 10 uM)|RI',
#  132: 'CYP3A4  Inhibitor (IC50 < 50 uM)|CYP3A4  Inhibitor (IC50 < 50 uM)',
#  133: 'CYP3A4  Inhibitor (IC50 < 50 uM)|RI',
#  134: 'CYP2D6  Inhibitor (IC50 < 50 uM)|CYP2D6  Inhibitor (IC50 < 50 uM)',
#  135: 'CYP2D6  Inhibitor (IC50 < 50 uM)|RI',
#  136: 'CYP2C9  Inhibitor (IC50 < 50 uM)|CYP2C9  Inhibitor (IC50 < 50 uM)',
#  137: 'CYP2C9  Inhibitor (IC50 < 50 uM)|RI',
#  138: 'CYP2C19  Inhibitor (IC50 < 50 uM)|CYP2C19  Inhibitor (IC50 < 50 uM)',
#  139: 'CYP2C19  Inhibitor (IC50 < 50 uM)|RI',
#  140: 'CYP1A2  Inhibitor (IC50 < 50 uM)|CYP1A2  Inhibitor (IC50 < 50 uM)',
#  141: 'CYP1A2  Inhibitor (IC50 < 50 uM)|RI',
#  142: 'Probability (S(7.4) > 0.01 mg/ml)',
#  143: 'Reliability Index of Probability (S(7.4) > 0.01 mg/ml)',
#  144: 'Probability (S(7.4) > 0.1 mg/ml)',
#  145: 'Reliability Index of Probability (S(7.4) > 0.1 mg/ml)',
#  146: 'Probability (S(7.4) > 1 mg/ml)',
#  147: 'Reliability Index of Probability (S(7.4) > 1 mg/ml)',
#  148: 'Probability (S(7.4) > 10 mg/ml)',
#  149: 'Reliability Index of Probability (S(7.4) > 10 mg/ml)',
#  150: 'CYP2C19 Regioselectivity|Score',
#  151: 'CYP2C19 Regioselectivity|Reliability',
#  152: 'CYP2C19 Regioselectivity|AtomNo',
#  153: 'CYP2C19 Regioselectivity|ReactionType',
#  154: 'LD50 (Mouse IP)|LD50 (Mouse IP)',
#  155: 'LD50 (Mouse IP)|RI',
#  156: 'LD50 (Mouse OR)|LD50 (Mouse OR)',
#  157: 'LD50 (Mouse OR)|RI',
#  158: 'LD50 (Mouse IV)|LD50 (Mouse IV)',
#  159: 'LD50 (Mouse IV)|RI',
#  160: 'LD50 (Mouse SC)|LD50 (Mouse SC)',
#  161: 'LD50 (Mouse SC)|RI',
#  162: 'LD50 (Rat IP)|LD50 (Rat IP)',
#  163: 'LD50 (Rat IP)|RI',
#  164: 'LD50 (Rat OR)|LD50 (Rat OR)',
#  165: 'LD50 (Rat OR)|RI',
#  166: 'Pe (Jejunum), 10^-4 cm/s',
#  167: 'ka, min^-1',
#  168: 'Maximum passive absorption (%)',
#  169: 'Contribution of transcellular route to absorption (%)',
#  170: 'Contribution of paracellular route to absorption (%)',
#  171: 'Molecular Weight (1)',
#  172: 'No. of Hydrogen Bond Donors (1)',
#  173: 'No. of Hydrogen Bond Acceptors (1)',
#  174: 'TPSA (1)',
#  175: 'No. of Rotatable Bonds (1)',
#  176: 'C Ratio (1)',
#  177: 'N Ratio (1)',
#  178: 'NO Ratio (1)',
#  179: 'Hetero Ratio (1)',
#  180: 'Halogen Ratio (1)',
#  181: 'Number of Rings (1)',
#  182: 'Number of Aromatic Rings (1)',
#  183: 'Number of Rings (size 3) (1)',
#  184: 'Number of Rings (size 4) (1)',
#  185: 'Number of Rings (size 5) (1)',
#  186: 'Number of Rings (size 6) (1)',
#  187: 'Log(BCF)',
#  188: 'Log(Koc)',
#  189: 'Dielectric Constant (1)',
#  190: 'Parachor (1)',
#  191: 'Index of Refraction (1)',
#  192: 'Surface Tension (1)',
#  193: 'Density (1)',
#  194: 'Polarizability (1)',
#  195: 'Molar Volume (1)',
#  196: 'Molar Refractivity (1)',
#  197: 'LogP (3)',
#  198: 'Isoelectric Point (2)',
#  199: 'pKa(Acid) (2)|pKa',
#  200: 'pKa(Acid) (2)|Conf. limits',
#  201: 'pKa(Acid) (2)|AtomNo',
#  202: 'pKa(Base) (2)|pKa',
#  203: 'pKa(Base) (2)|Conf. limits',
#  204: 'pKa(Base) (2)|AtomNo',
#  205: 'LogS (pH = 7.40) (1)',
#  206: 'LogD (pH = 7.40)',
#  207: 'PepT1 Substrate',
#  208: 'ASBT Substrate',
#  209: 'MCT1 Substrate',
#  210: 'Amino Acid Transport',
#  211: 'Other Transport',
#  212: 'LogRBA > -3|LogRBA > -3',
#  213: 'LogRBA > -3|RI',
#  214: 'LogRBA > 0|LogRBA > 0',
#  215: 'LogRBA > 0|RI',
#  216: 'LogP (4)',
#  217: 'Probability of Eye Irritation',
#  218: 'Probability of Skin Irritation',
#  219: 'Probability of Health Effects (Blood)',
#  220: 'Probability of Health Effects (Cardiovascular)',
#  221: 'Probability of Health Effects (Gastrointestinal)',
#  222: 'Probability of Health Effects (Kidney)',
#  223: 'Probability of Health Effects (Liver)',
#  224: 'Probability of Health Effects (Lungs)',
#  225: 'LC50 (Fathead Minnow)|LC50 (Fathead Minnow)',
#  226: 'LC50 (Fathead Minnow)|RI',
#  227: 'LC50 (Water flea)|LC50 (Water flea)',
#  228: 'LC50 (Water flea)|RI',
#  229: 'IGC50 (Ciliate protozoa)|IGC50 (Ciliate protozoa)',
#  230: 'IGC50 (Ciliate protozoa)|RI',
#  231: 'LogD (pH = 7.40) (1)',
#  232: 'HLM Regioselectivity|Score',
#  233: 'HLM Regioselectivity|Reliability',
#  234: 'HLM Regioselectivity|AtomNo',
#  235: 'HLM Regioselectivity|ReactionType',
#  236: '%PPB|%PPB',
#  237: '%PPB|RI',
#  238: 'LogKa(HSA)|LogKa(HSA)',
#  239: 'LogKa(HSA)|RI',
#  240: 'Probability(LD50 =< 5 mg/kg)',
#  241: 'Probability(LD50 =< 50 mg/kg)',
#  242: 'Probability(LD50 =< 300 mg/kg)',
#  243: 'Probability(LD50 =< 2000 mg/kg)',
#  244: 'Probability(LD50 =< 5000 mg/kg)',
#  245: 'Vd (L/kg)',
#  246: 'Pe (Caco-2) with LogP, 10^-6 cm/s (pH = 6.50, rpm = 0.00)',
#  247: 'Pe (Caco-2) with LogP, 10^-6 cm/s (pH = 6.50, rpm = 500.00)',
#  248: 'Pe (Caco-2) with LogP, 10^-6 cm/s (pH = 7.40, rpm = 0.00)',
#  249: 'Pe (Caco-2) with LogP, 10^-6 cm/s (pH = 7.40, rpm = 500.00)',
#  250: 'Pe (Caco-2) with LogP, 10^-6 cm/s (pH = 8.00, rpm = 0.00)',
#  251: 'Pe (Caco-2) with LogP, 10^-6 cm/s (pH = 8.00, rpm = 500.00)',
#  252: 'Pe (Caco-2) with LogD, 10^-6 cm/s (pH = 6.50, rpm = 0.00)',
#  253: 'Pe (Caco-2) with LogD, 10^-6 cm/s (pH = 6.50, rpm = 500.00)',
#  254: 'Pe (Caco-2) with LogD, 10^-6 cm/s (pH = 7.40, rpm = 0.00)',
#  255: 'Pe (Caco-2) with LogD, 10^-6 cm/s (pH = 7.40, rpm = 500.00)',
#  256: 'Pe (Caco-2) with LogD, 10^-6 cm/s (pH = 8.00, rpm = 0.00)',
#  257: 'Pe (Caco-2) with LogD, 10^-6 cm/s (pH = 8.00, rpm = 500.00)',
#  258: 'SMILES'}

# %%
col_df = pd.DataFrame.from_dict(col_dic, orient='index')

# %%
col_df.to_csv('/Users/song-inhyeok/Desktop/admet_data/chembl_data/result_file/col_list.csv')

# %%
df = pd.read_csv('/Users/song-inhyeok/Desktop/admet_data/id_1_total_test.csv')
df=df.replace(np.nan, None, regex=True)

id_list = df['id'].tolist()
count = 0
for i in id_list:        
    count += 1
    molecule = self.session.query(Molecule).filter(Molecule.id==i).first() 
    #print(i, molecule, molecule.id)
                
    mw = df.loc[df['id']==i].values[0][57]
    logp = df.loc[df['id']==i].values[0][115]
    tpsa = df.loc[df['id']==i].values[0][174]
    h_donors = df.loc[df['id']==i].values[0][58]
    h_acceptors = df.loc[df['id']==i].values[0][59]
    rot_bonds = df.loc[df['id']==i].values[0][61]
    rings = df.loc[df['id']==i].values[0][67]
    #print(mw, logp, tpsa, h_don, h_acc, rot, ring)
    
    #absorp
    a = df.loc[df['id']==i].values[0][91]
    b = df.loc[df['id']==i].values[0][92]
    bo = df.loc[df['id']==i].values[0][93]
    l = df.loc[df['id']==i].values[0][94]
    s = df.loc[df['id']==i].values[0][95]
    e = df.loc[df['id']==i].values[0][96]
    mcgowanvolume = df.loc[df['id']==i].values[0][97]
    #print(a, b, bo, l, s, e, mcgowanvolume)
    
    abs_oral_dose_02mg = df.loc[df['id']==i].values[0][81]
    abs_oral_dose_1mg = df.loc[df['id']==i].values[0][82]
    abs_oral_dose_5mg = df.loc[df['id']==i].values[0][83]
    abs_oral_dose_20mg = df.loc[df['id']==i].values[0][84]
    abs_oral_dose_50mg = df.loc[df['id']==i].values[0][85]
    abs_oral_dose_100mg = df.loc[df['id']==i].values[0][86]
    abs_oral_dose_500mg = df.loc[df['id']==i].values[0][87]
    pe = df.loc[df['id']==i].values[0][166]
    ka = df.loc[df['id']==i].values[0][167]
    maxhia = df.loc[df['id']==i].values[0][168]
    #print(abs_oral_dose_02mg, abs_oral_dose_1mg,abs_oral_dose_5mg, abs_oral_dose_20mg,  abs_oral_dose_50mg ,  abs_oral_dose_100mg,  abs_oral_dose_500mg, pe, ka, maxhia)
    
    pecaco2_ph65_0rpm = df.loc[df['id']==i].values[0][140]
    pecaco2_ph65_500rpm = df.loc[df['id']==i].values[0][141] 
    pecaco2_ph74_0rpm = df.loc[df['id']==i].values[0][142]
    pecaco2_ph74_500rpm = df.loc[df['id']==i].values[0][143]  
    pecaco2_ph80_0rpm = df.loc[df['id']==i].values[0][144]
    pecaco2_ph80_500rpm = df.loc[df['id']==i].values[0][145]
    mrdd  = df.loc[df['id']==i].values[0][47]
    mrddclass = df.loc[df['id']==i].values[0][48]
    

    #distribution
    logps = df.loc[df['id']==i].values[0][32]
    logbb = df.loc[df['id']==i].values[0][33]
    fu_brain = df.loc[df['id']==i].values[0][34]
    bbb_eq_rate = df.loc[df['id']==i].values[0][90] 
    _ppb = df.loc[df['id']==i].values[0][123] 
    _ppb_ri = df.loc[df['id']==i].values[0][124]
    logka_hsa = df.loc[df['id']==i].values[0][125]
    logka_hsa_ri = df.loc[df['id']==i].values[0][126] 
    vss = df.loc[df['id']==i].values[0][40]
    actr_asbt_substrate = df.loc[df['id']==i].values[0][102]
    actr_pept1_substrate = df.loc[df['id']==i].values[0][103]
    actr_mct1_substrate = df.loc[df['id']==i].values[0][104]
    actr_amino_acid_transport = df.loc[df['id']==i].values[0][105]
    actr_other_transport = df.loc[df['id']==i].values[0][106]


    #metabolism
    _pgp_s = df.loc[df['id']==i].values[0][16]
    _pgp_s_ri = df.loc[df['id']==i].values[0][17]
    _pgp_s_good = df.loc[df['id']==i].values[0][18]
    _pgp_s_good_ri = df.loc[df['id']==i].values[0][19]
    _pgp_i = df.loc[df['id']==i].values[0][128]
    _pgp_i_ri = df.loc[df['id']==i].values[0][129]
    _pgp_i_good = df.loc[df['id']==i].values[0][130]
    _pgp_i_good_ri = df.loc[df['id']==i].values[0][131]
    _cyp3a4_i_10 = df.loc[df['id']==i].values[0][20]
    _cyp3a4_i_10_ri = df.loc[df['id']==i].values[0][21]
    _cyp2d6_i_10 = df.loc[df['id']==i].values[0][22]
    _cyp2d6_i_10_ri = df.loc[df['id']==i].values[0][23]
    _cyp2c9_i_10 = df.loc[df['id']==i].values[0][24]
    _cyp2c9_i_10_ri = df.loc[df['id']==i].values[0][25]
    _cyp2c19_i_10 = df.loc[df['id']==i].values[0][26]
    _cyp2c19_i_10_ri = df.loc[df['id']==i].values[0][27]
    _cyp1a2_i_10 = df.loc[df['id']==i].values[0][28]
    _cyp1a2_i_10_ri =df.loc[df['id']==i].values[0][29]
    _cyp3a4_i_50 = df.loc[df['id']==i].values[0][30]
    _cyp3a4_i_50_ri = df.loc[df['id']==i].values[0][31]
    _cyp2d6_i_50 = df.loc[df['id']==i].values[0][32]
    _cyp2d6_i_50_ri = df.loc[df['id']==i].values[0][33]
    _cyp2c9_i_50 = df.loc[df['id']==i].values[0][34]
    _cyp2c9_i_50_ri = df.loc[df['id']==i].values[0][35]
    _cyp2c19_i_50 = df.loc[df['id']==i].values[0][36]
    _cyp2c19_i_50_ri = df.loc[df['id']==i].values[0][37]
    _cyp1a2_i_50 = df.loc[df['id']==i].values[0][38]
    _cyp1a2_i_50_ri = df.loc[df['id']==i].values[0][39]
    _cyp3a4_s = df.loc[df['id']==i].values[0][111]
    _cyp3a4_s_ri = df.loc[df['id']==i].values[0][112]
    _cyp2d6_s = df.loc[df['id']==i].values[0][113]
    _cyp2d6_s_ri = df.loc[df['id']==i].values[0][114]
    _cyp2c9_s = df.loc[df['id']==i].values[0][115]
    _cyp2c9_s_ri = df.loc[df['id']==i].values[0][116]
    _cyp2c19_s = df.loc[df['id']==i].values[0][117]
    _cyp2c19_s_ri = df.loc[df['id']==i].values[0][118]
    _cyp1a2_s = df.loc[df['id']==i].values[0][119]
    _cyp1a2_s_ri = df.loc[df['id']==i].values[0][120]

    #toxicity
    _ld50_mouse_ip = df.loc[df['id']==i].values[0][71]
    _ld50_mouse_ip_ri = df.loc[df['id']==i].values[0][72]
    _ld50_mouse_or = df.loc[df['id']==i].values[0][73]
    _ld50_mouse_or_ri = df.loc[df['id']==i].values[0][74]
    _ld50_mouse_iv = df.loc[df['id']==i].values[0][75]
    _ld50_mouse_iv_ri = df.loc[df['id']==i].values[0][76]
    _ld50_mouse_sc = df.loc[df['id']==i].values[0][77]
    _ld50_mouse_sc_ri = df.loc[df['id']==i].values[0][78]
    _ld50_rat_ip = df.loc[df['id']==i].values[0][79]
    _ld50_rat_ip_ri = df.loc[df['id']==i].values[0][80]
    _ld50_rat_or = df.loc[df['id']==i].values[0][81]
    _ld50_rat_or_ri = df.loc[df['id']==i].values[0][82]
    _lc50_ppromelas = df.loc[df['id']==i].values[0][98]
    _lc50_ppromelas_ri = df.loc[df['id']==i].values[0][99]
    _lc50_dmagna = df.loc[df['id']==i].values[0][100]
    _lc50_dmagna_ri = df.loc[df['id']==i].values[0][101]
    _igc50_tpyriformis = df.loc[df['id']==i].values[0][137]
    _igc50_tpyriformis_ri = df.loc[df['id']==i].values[0][138]
    _ames = df.loc[df['id']==i].values[0][121]
    _ames_ri = df.loc[df['id']==i].values[0][122]
    _logrba_3 = df.loc[df['id']==i].values[0][83]
    _logrba_3_ri = df.loc[df['id']==i].values[0][84]
    _logrba_0 = df.loc[df['id']==i].values[0][85]
    _logrba_0_ri = df.loc[df['id']==i].values[0][86]
    probability_of_he_on_blood = df.loc[df['id']==i].values[0][41]
    probability_of_he_on_cardiovascular_system = df.loc[df['id']==i].values[0][42]
    probability_of_he_on_gastrointestinal_system = df.loc[df['id']==i].values[0][43]
    probability_of_he_on_kidney = df.loc[df['id']==i].values[0][44] 
    probability_of_he_on_liver = df.loc[df['id']==i].values[0][45]
    probability_of_he_on_lungs = df.loc[df['id']==i].values[0][46]
    _herg = df.loc[df['id']==i].values[0][69]
    _herg_ri = df.loc[df['id']==i].values[0][70]
    eye_irritation = df.loc[df['id']==i].values[0][107]
    skin_irritation = df.loc[df['id']==i].values[0][127]
            
    #leadlike_category
    mw_class_val = df.loc[df['id']==i].values[0][154]
    logp_class_val = df.loc[df['id']==i].values[0][153]
    solubility_class_val = df.loc[df['id']==i].values[0][159]
    perme_val = df.loc[df['id']==i].values[0][160]
    hia_val = df.loc[df['id']==i].values[0][161]
    meta_val = df.loc[df['id']==i].values[0][162]
    ames_val =df.loc[df['id']==i].values[0][163]
    herg_val =df.loc[df['id']==i].values[0][164]
